# %%
from miditok import REMI, get_midi_programs
from miditoolkit import MidiFile
import numpy as np
from pathlib import Path
import json 
import os, glob
from torch.utils.data import Dataset,DataLoader
import torch as T
import pandas as pd

# %%
# Our parameters
pitch_range = range(21, 109)
beat_res = {(0, 4): 8, (4, 12): 4}
nb_velocities = 32
additional_tokens = {'Chord': True, 'Rest': True, 'Tempo': True, 'Program': False, 'TimeSignature': False,
                     'rest_range': (2, 8),  # (half, 8 beats)
                     'nb_tempos': 32,  # nb of tempo bins
                     'tempo_range': (40, 250)}  # (min, max)

# Creates the tokenizer and loads a MIDI
tokenizer = REMI(pitch_range, beat_res, nb_velocities, additional_tokens, mask=True)
midi = MidiFile('../datasets/midi/midi_files/train/100005.mid')

# %%
from miditok import REMI
from pathlib import Path

# Creates the tokenizer and list the file paths
tokenizer = REMI(mask=True)  # using defaults parameters (constants.py), with MASK tokens for pre-training
train_paths = list(Path('../datasets/midi/midi_files/train/').glob('*.mid'))
val_paths = list(Path('../datasets/midi/midi_files/valid/').glob('*.mid'))
test_paths = list(Path('../datasets/midi/midi_files/eval/').glob('*.mid'))
# A validation method to discard MIDIs we do not want
# It can also be used for custom pre-processing, for instance if you want to merge
# some tracks before tokenizing a MIDI file
def midi_valid(midi) -> bool:
    if any(ts.numerator != 4 for ts in midi.time_signature_changes):
        return False  # time signature different from 4/*, 4 beats per bar
    if midi.max_tick < 10 * midi.ticks_per_beat:
        return False  # this MIDI is too short
    return True

# Converts MIDI files to tokens saved as JSON files
tokenizer.tokenize_midi_dataset(train_paths, 'tokenized_train', lambda x: True)
tokenizer.tokenize_midi_dataset(val_paths, 'tokenized_val', lambda x: True)
tokenizer.tokenize_midi_dataset(test_paths, 'tokenized_test', lambda x: True)
# Out:
# Converting MIDIs to tokens:  10%|█         | 999/9552 [00:03<00:27, 314.99it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 20
#      17     return True
#      19 # Converts MIDI files to tokens saved as JSON files
# ---> 20 tokenizer.tokenize_midi_dataset(train_paths, 'tokenized_train', lambda x: True)
#      21 tokenizer.tokenize_midi_dataset(val_paths, 'tokenized_val', lambda x: True)
#      22 tokenizer.tokenize_midi_dataset(test_paths, 'tokenized_test', lambda x: True)
#
# File ~/anaconda3/envs/diffusion_linux/lib/python3.12/site-packages/miditok/midi_tokenizer_base.py:516, in MIDITokenizer.tokenize_midi_dataset(self, midi_paths, out_dir, validation_fn, save_programs, logging)
#     513 for midi_path in tqdm(midi_paths, desc='Converting MIDIs to tokens') if logging else enumerate(midi_paths):
#     514     # Some MIDIs can contains errors that are raised by Mido, if so the loop continues
#     515     try:
# --> 516         midi = MidiFile(PurePath(midi_path))
#     517     except FileNotFoundError:
#     518         if logging:
#
# File ~/anaconda3/envs/diffusion_linux/lib/python3.12/site-packages/miditoolkit/midi/parser.py:52, in MidiFile.__init__(self, filename, file, ticks_per_beat, clip, charset)
#      50 if filename or file:
#      51     if filename:
# ---> 52         mido_obj = mido.MidiFile(filename=filename, clip=clip, charset=charset)
#      53     else:
#      54         mido_obj = mido.MidiFile(file=file, clip=clip, charset=charset)
#
# File ~/anaconda3/envs/diffusion_linux/lib/python3.12/site-packages/mido/midifiles/midifiles.py:320, in MidiFile.__init__(self, filename, file, type, ticks_per_beat, charset, debug, clip, tracks)
#     318 elif self.filename is not None:
#     319     with open(filename, 'rb') as file:
# --> 320         self._load(file)
#
# File ~/anaconda3/envs/diffusion_linux/lib/python3.12/site-packages/mido/midifiles/midifiles.py:371, in MidiFile._load(self, infile)
#     368 if self.debug:
#     369     _dbg(f'Track {i}:')
# --> 371 self.tracks.append(read_track(infile,
#     372                               debug=self.debug,
#     373                               clip=self.clip))
#
# File ~/anaconda3/envs/diffusion_linux/lib/python3.12/site-packages/mido/midifiles/midifiles.py:218, in read_track(infile, debug, clip)
#     216     msg = read_sysex(infile, delta, clip)
#     217 else:
# --> 218     msg = read_message(infile, status_byte, peek_data, delta, clip)
#     220 track.append(msg)
#     222 if debug:
#
# File ~/anaconda3/envs/diffusion_linux/lib/python3.12/site-packages/mido/midifiles/midifiles.py:133, in read_message(infile, status_byte, peek_data, delta, clip)
#     130         if byte > 127:
#     131             raise OSError('data byte must be in range 0..127')
# --> 133 return Message.from_bytes([status_byte] + data_bytes, time=delta)
#
# File ~/anaconda3/envs/diffusion_linux/lib/python3.12/site-packages/mido/messages/messages.py:163, in Message.from_bytes(cl, data, time)
#     156 """Parse a byte encoded message.
#     157
#     158 Accepts a byte string or any iterable of integers.
#     159
#     160 This is the reverse of msg.bytes() or msg.bin().
#     161 """
#     162 msg = cl.__new__(cl)
# --> 163 msgdict = decode_message(data, time=time)
#     164 if 'data' in msgdict:
#     165     msgdict['data'] = SysexData(msgdict['data'])
#
# File ~/anaconda3/envs/diffusion_linux/lib/python3.12/site-packages/mido/messages/decode.py:111, in decode_message(msg_bytes, time, check)
#     109     msg.update(_SPECIAL_CASES[status_byte](data))
#     110 else:
# --> 111     msg.update(_decode_data_bytes(status_byte, data, spec))
#     113 return msg
#
# File ~/anaconda3/envs/diffusion_linux/lib/python3.12/site-packages/mido/messages/decode.py:57, in _decode_data_bytes(status_byte, data, spec)
#      55 # TODO: better name than args?
#      56 names = [name for name in spec['value_names'] if name != 'channel']
# ---> 57 args = {name: value for name, value in zip(names, data)}
#      59 if status_byte in CHANNEL_MESSAGES:
#      60     # Channel is stored in the lower nibble of the status byte.
#      61     args['channel'] = status_byte & 0x0f
#
# KeyboardInterrupt:

# %%
def preprocess(X,length):
    result = []
    for i in range(len(X)):
        if len(X[i]) > length:
            result.append(X[i][:length])
        elif len(X[i]) < length:
            result.append(X[i] + [0]*(length-len(X[i])))
        else:
            result.append(X[i])
    return result 

def data_loader(path,length):
    data = []
    labels = []
    for filename in glob.glob(os.path.join(path, '*.json')):
        with open(os.path.join(os.getcwd(), filename), 'r') as f:
            d = json.load(f)
            data.append(d['tokens'][0])
            labels.append(d['programs'][0][0])
    return preprocess(data,length),labels

# %%
X_train,y_train = data_loader('tokenized_train/',16*16)
X_val,y_val = data_loader('tokenized_val/',16*16)
X_test,y_test = data_loader('tokenized_test/',16*16)

# %%
class midi_data(Dataset):
    def __init__(self, X,y):
        self.X = X
        self.y = y
        
    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x = T.tensor(self.X[idx],dtype=torch.float32)
        label = self.y[idx]
        
        return x, label

# %%
train_dataset = midi_data(X_train,y_train)
val_dataset = midi_data(X_val,y_val)
test_dataset = midi_data(X_test,y_test)
print(len(X_val))
# Out:
# 2400

# %%
EPOCHS = 300
BATCH_SIZE = 16
LEARNING_RATE = 0.0007
NUM_FEATURES = len(X_train[0])
NUM_CLASSES = 128
NUM_FEATURES
# Out:
# 256

# %%
import torch.nn as nn
import torch.optim as optim
class MulticlassClassification(nn.Module):
    def __init__(self, num_feature, num_class):
        super(MulticlassClassification, self).__init__()
        
        self.layer_1 = nn.Linear(num_feature, 1024)
        self.layer_2 = nn.Linear(1024, 512)
        self.layer_3 = nn.Linear(512, 256)
        self.layer_out = nn.Linear(256, num_class) 
        
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=0.3)
        self.batchnorm1 = nn.BatchNorm1d(1024)
        self.batchnorm2 = nn.BatchNorm1d(512)
        self.batchnorm3 = nn.BatchNorm1d(256)
        
    def forward(self, x):
        x = self.layer_1(x)
        x = self.batchnorm1(x)
        x = self.relu(x)
        
        x = self.layer_2(x)
        x = self.batchnorm2(x)
        x = self.relu(x)
        x = self.dropout(x)
        
        x = self.layer_3(x)
        x = self.batchnorm3(x)
        x = self.relu(x)
        x = self.dropout(x)
        
        x = self.layer_out(x)
        
        return x

# %%
train_loader = DataLoader(dataset=train_dataset,
                          batch_size=BATCH_SIZE,)
val_loader = DataLoader(dataset=val_dataset, batch_size=1)
test_loader = DataLoader(dataset=test_dataset, batch_size=1)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
model = MulticlassClassification(num_feature = NUM_FEATURES, num_class=NUM_CLASSES)
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
print(model)
# Out:
# MulticlassClassification(
#   (layer_1): Linear(in_features=256, out_features=1024, bias=True)
#   (layer_2): Linear(in_features=1024, out_features=512, bias=True)
#   (layer_3): Linear(in_features=512, out_features=256, bias=True)
#   (layer_out): Linear(in_features=256, out_features=128, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.5, inplace=False)
#   (batchnorm1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm2): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batchnorm3): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
def multi_acc(y_pred, y_test):
    y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)    
    
    correct_pred = (y_pred_tags == y_test).float()
    acc = correct_pred.sum() / len(correct_pred)
    
    acc = torch.round(acc * 100)
    
    return acc

accuracy_stats = {
    'train': [],
    "val": []
}
loss_stats = {
    'train': [],
    "val": []
}

# %%
from tqdm.notebook import tqdm
print("Begin training.")
for e in tqdm(range(1, EPOCHS+1)):
    
    # TRAINING
    train_epoch_loss = 0
    train_epoch_acc = 0
    model.train()
    for X_train_batch, y_train_batch in train_loader:
        X_train_batch, y_train_batch = X_train_batch.to(device), y_train_batch.to(device)
        optimizer.zero_grad()
        
        y_train_pred = model(X_train_batch)
        
        train_loss = criterion(y_train_pred, y_train_batch)
        train_acc = multi_acc(y_train_pred, y_train_batch)
        
        train_loss.backward()
        optimizer.step()
        
        train_epoch_loss += train_loss.item()
        train_epoch_acc += train_acc.item()
        
        
    # VALIDATION    
    with torch.no_grad():
        
        val_epoch_loss = 0
        val_epoch_acc = 0
        
        model.eval()
        for X_val_batch, y_val_batch in val_loader:
            X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
            
            y_val_pred = model(X_val_batch)
                        
            val_loss = criterion(y_val_pred, y_val_batch)
            val_acc = multi_acc(y_val_pred, y_val_batch)
            
            val_epoch_loss += val_loss.item()
            val_epoch_acc += val_acc.item()
    loss_stats['train'].append(train_epoch_loss/len(train_loader))
    loss_stats['val'].append(val_epoch_loss/len(val_loader))
    accuracy_stats['train'].append(train_epoch_acc/len(train_loader))
    accuracy_stats['val'].append(val_epoch_acc/len(val_loader))
                              
    
    print(f'Epoch {e+0:03}: | Train Loss: {train_epoch_loss/len(train_loader):.5f} | Val Loss: {val_epoch_loss/len(val_loader):.5f} | Train Acc: {train_epoch_acc/len(train_loader):.3f}| Val Acc: {val_epoch_acc/len(val_loader):.3f}')
# Out:
# Begin training.
#   0%|          | 0/300 [00:00<?, ?it/s]
# Epo
# Epoch 113: | Train Loss: 0.08191 | Val Loss: 9.81505 | Train Acc: 97.571| Val Acc: 26.250
# Epoch 114: | Train Loss: 0.07030 | Val Loss: 9.12233 | Train Acc: 97.871| Val Acc: 23.917
# Epoch 115: | Train Loss: 0.07767 | Val Loss: 9.32342 | Train Acc: 97.675| Val Acc: 24.125
# Epoch 116: | Train Loss: 0.07356 | Val Loss: 8.79566 | Train Acc: 97.844| Val Acc: 23.000
# Epoch 117: | Train Loss: 0.08932 | Val Loss: 9.01445 | Train Acc: 97.166| Val Acc: 23.917
# Epoch 118: | Train Loss: 0.07741 | Val Loss: 9.32974 | Train Acc: 97.765| Val Acc: 25.792
# Epoch 119: | Train Loss: 0.06847 | Val Loss: 9.16805 | Train Acc: 97.901| Val Acc: 25.375
# Epoch 120: | Train Loss: 0.07046 | Val Loss: 9.22824 | Train Acc: 97.898| Val Acc: 24.958
# Epoch 121: | Train Loss: 0.06752 | Val Loss: 9.72927 | Train Acc: 97.955| Val Acc: 23.667
# Epoch 122: | Train Loss: 0.08605 | Val Loss: 9.83483 | Train Acc: 97.585| Val Acc: 25.083
# Epoch 123: | Train Loss: 0.07036 | Val Loss: 9.68516 | Train Acc: 97.905| Val Acc: 24.917
# Epoch 124: | Train Loss: 0.07122 | Val Loss: 9.60184 | Train Acc: 97.831| Val Acc: 23.958
# Epoch 125: | Train Loss: 0.07154 | Val Loss: 9.76510 | Train Acc: 97.940| Val Acc: 25.167
# Epoch 126: | Train Loss: 0.07808 | Val Loss: 9.90051 | Train Acc: 97.762| Val Acc: 24.958
# Epoch 127: | Train Loss: 0.07265 | Val Loss: 9.24108 | Train Acc: 97.926| Val Acc: 25.292
# Epoch 128: | Train Loss: 0.05671 | Val Loss: 9.38658 | Train Acc: 98.229| Val Acc: 24.708
# Epoch 129: | Train Loss: 0.06966 | Val Loss: 10.15460 | Train Acc: 97.754| Val Acc: 25.792
# Epoch 130: | Train Loss: 0.06197 | Val Loss: 9.90883 | Train Acc: 98.208| Val Acc: 26.375
# Epoch 131: | Train Loss: 0.06526 | Val Loss: 10.15889 | Train Acc: 98.117| Val Acc: 25.792
# Epoch 132: | Train Loss: 0.06943 | Val Loss: 9.65679 | Train Acc: 97.873| Val Acc: 24.833
# Epoch 133: | Train Loss: 0.06398 | Val Loss: 9.45001 | Train Acc: 98.025| Val Acc: 24.708
# Epoch 134: | Train Loss: 0.05899 | Val Loss: 9.54485 | Train Acc: 98.236| Val Acc: 24.917
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[80], line 33
#      31 model.eval()
#      32 for X_val_batch, y_val_batch in val_loader:
# ---> 33     X_val_batch, y_val_batch = X_val_batch.to(device), y_val_batch.to(device)
#      35     y_val_pred = model(X_val_batch)
#      37     val_loss = criterion(y_val_pred, y_val_batch)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Create dataframes
train_val_acc_df = pd.DataFrame.from_dict(accuracy_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
train_val_loss_df = pd.DataFrame.from_dict(loss_stats).reset_index().melt(id_vars=['index']).rename(columns={"index":"epochs"})
# Plot the dataframes
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,7))
sns.lineplot(data=train_val_acc_df, x = "epochs", y="value", hue="variable",  ax=axes[0]).set_title('Train-Val Accuracy/Epoch')
sns.lineplot(data=train_val_loss_df, x = "epochs", y="value", hue="variable", ax=axes[1]).set_title('Train-Val Loss/Epoch')
# Out:
# Text(0.5, 1.0, 'Train-Val Loss/Epoch')
